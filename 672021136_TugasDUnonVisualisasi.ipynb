# %%
import pandas as pd

# %%
# Membaca data dari file CSV
df = pd.read_csv('sample.csv')

# %%
df
# Out:
#           Date      Time  CustomerID  CardID  GasStationID  ProductID  \
# 0   2012-01-01  00:18:00       41113  645177           363          2
# 1   2012-01-01  02:05:00       30766  496967          1083          2
# 2   2012-01-01  00:27:00       31576  618868           109          5
# 3   2012-01-01  06:56:00        3800  598481          5298        322
# 4   2012-01-01  05:46:00        3493   34405          5163        317
# ..         ...       ...         ...     ...           ...        ...
# 84  2012-01-01  12:16:00       26960  503183           145          5
# 85  2012-01-01  07:27:00       40258  442921          3501          2
# 86  2012-01-01  10:05:00       22752  590089          3419          5
# 87  2012-01-01  11:58:00       11597  141185          2965          5
# 88  2012-01-01  11:58:00       11597  141185          2965         11
#
#       Amount      Price
# 0    93.7500  2038.5750
# 1   132.1000  3002.6920
# 2    21.3500   462.9240
# 3    52.5000    47.0239
# ...

# %%
# Menampilkan lima transaksi teratas berdasarkan jumlahnya, hanya memperhatikan kolom customer dan transaksi
Transaksi1 = df.nlargest(5, ['Amount', 'CustomerID'])

CST = Transaksi1[['Amount', 'CustomerID']]
CST
# Out:
#       Amount  CustomerID
# 14  231.2750        6769
# 70  150.1375       15470
# 1   132.1000       30766
# 30  130.7750        7196
# 17  100.0000        9606

# %%
# Menampilkan lima transaksi teratas berdasarkan jumlahnya, hanya memperhatikan kolom customer dan transaksi
transaksi2 = df.nlargest(5, ['Amount'])

GAS = transaksi2[['Amount', 'GasStationID']]
GAS
# Out:
#       Amount  GasStationID
# 14  231.2750           405
# 70  150.1375          2367
# 1   132.1000          1083
# 30  130.7750          3333
# 17  100.0000          4356

# %%
# Menampilkan lima transaksi teratas berdasarkan jumlahnya, hanya memperhatikan kolom customer dan transaksi
#transaksi3 = df.nlargest(5, ['Amount', 'Date', 'Time'])

transaksi3 = df.nlargest(5, ['Amount'])
WKT = transaksi3[['Amount', 'Date', 'Time']]
WKT
# Out:
#       Amount        Date      Time
# 14  231.2750  2012-01-01  07:18:00
# 70  150.1375  2012-01-01  09:53:00
# 1   132.1000  2012-01-01  02:05:00
# 30  130.7750  2012-01-01  04:40:00
# 17  100.0000  2012-01-01  08:13:00

# %% [markdown]
# Tujuan utama dari analisis data customer ini adalah?
# Untuk menganalisis perilaku pelanggan. Dengan menganalisis data perilaku pelanggan, sebagai pengusaha yang menjalankan usaha gasstation, dengan membagi pelanggan dalam segmen dengan karakteristik yang sama, ini memungkinkan kita untuk menyajikan penawaran yang lebih relevan kepada masing-masing pelanggan. Selain itu, dengan analisis data pelanggan ini dapat mambantu dalam memprediksi perilaku masa depan pelanggan seperti jam berapa para pelanggan sering membeli gas. Manfaat lainnya yang dapat diperoleh dari analisis data pelanggan ini adalah optimasi layanan pelanggan, serta meningkatkan pendapatan
